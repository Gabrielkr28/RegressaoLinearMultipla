# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("./data_preg.csv", header=None)

plt.scatter(data[0], data[1]) #Cria grafico de dispersão

# %%
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("./data_preg.csv", header=None)

def regressao_polinomial(coeficientes_beta, X):
    grau = len(coeficientes_beta) - 1  
    y = 0

    for i in range(grau + 1):
        y += coeficientes_beta[i] * (X ** i)

    return y

X = np.array([1, 2, 3, 4, 5])  
y = np.array([2, 3, 5, 6, 9])  

grau_do_polinomio = 1  # Especifique o grau do polinômio desejado
coeficientes_beta = np.polyfit(data[0], data[1], grau_do_polinomio)

X_valor = 1  
resultado = regressao_polinomial(coeficientes_beta, X_valor)
print("Resultado da Regressão Polinomial:", resultado)
# Out:
# Resultado da Regressão Polinomial: 1.1566338125141107

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Leitura dos dados a partir do arquivo CSV
data = pd.read_csv("./data_preg.csv", header=None)

# Ajuste o polinômio usando numpy.polyfit para N = 1 (Regressão Linear)
grau_do_polinomio1 = 1
coeficientes_beta1 = np.polyfit(data[0], data[1], grau_do_polinomio1)

# Coeficientes invertidos para a regressão linear
coeficientes_invertidos1 = np.flip(coeficientes_beta1)

# Ajuste o polinômio usando numpy.polyfit para N = 2
grau_do_polinomio2 = 2
coeficientes_beta2 = np.polyfit(data[0], data[1], grau_do_polinomio2)

# Coeficientes invertidos para a regressão polinomial de grau 2
coeficientes_invertidos2 = np.flip(coeficientes_beta2)

# Crie a função de regressão polinomial
def regressao_polinomial(coeficientes, X):
    grau = len(coeficientes) - 1
    y = 0
    for i in range(grau + 1):
        y += coeficientes[i] * (X ** i)
    return y

# Valores previstos da linha de regressão para N = 1
X_valores1 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred1 = [regressao_polinomial(coeficientes_invertidos1, x) for x in X_valores1]

# Valores previstos da linha de regressão para N = 2
X_valores2 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred2 = [regressao_polinomial(coeficientes_invertidos2, x) for x in X_valores2]

# Plotar os dados de dispersão em vermelho e a linha de regressão em azul (N = 1)
# Plotar a linha de regressão em verde (N = 2)
plt.scatter(data[0], data[1], color='red', label='Dados de dispersão')
plt.plot(X_valores1, y_pred1, color='blue', label='Linha de Regressão (N = 1)')
plt.plot(X_valores2, y_pred2, color='green', label='Linha de Regressão (N = 2)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Leitura dos dados a partir do arquivo CSV
data = pd.read_csv("./data_preg.csv", header=None)

# Ajuste o polinômio usando numpy.polyfit para N = 1 (Regressão Linear)
grau_do_polinomio1 = 1
coeficientes_beta1 = np.polyfit(data[0], data[1], grau_do_polinomio1)

# Coeficientes invertidos para a regressão linear
coeficientes_invertidos1 = np.flip(coeficientes_beta1)

# Ajuste o polinômio usando numpy.polyfit para N = 2
grau_do_polinomio2 = 2
coeficientes_beta2 = np.polyfit(data[0], data[1], grau_do_polinomio2)

# Coeficientes invertidos para a regressão polinomial de grau 2
coeficientes_invertidos2 = np.flip(coeficientes_beta2)

# Ajuste o polinômio usando numpy.polyfit para N = 3
grau_do_polinomio3 = 3
coeficientes_beta3 = np.polyfit(data[0], data[1], grau_do_polinomio3)

# Coeficientes invertidos para a regressão polinomial de grau 3
coeficientes_invertidos3 = np.flip(coeficientes_beta3)

# Ajuste o polinômio usando numpy.polyfit para N = 8
grau_do_polinomio8 = 8
coeficientes_beta8 = np.polyfit(data[0], data[1], grau_do_polinomio8)

# Coeficientes invertidos para a regressão polinomial de grau 8
coeficientes_invertidos8 = np.flip(coeficientes_beta8)

# Crie a função de regressão polinomial
def regressao_polinomial(coeficientes, X):
    grau = len(coeficientes) - 1
    y = 0
    for i in range(grau + 1):
        y += coeficientes[i] * (X ** i)
    return y

# Valores previstos da linha de regressão para N = 1
X_valores1 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred1 = [regressao_polinomial(coeficientes_invertidos1, x) for x in X_valores1]

# Valores previstos da linha de regressão para N = 2
X_valores2 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred2 = [regressao_polinomial(coeficientes_invertidos2, x) for x in X_valores2]

# Valores previstos da linha de regressão para N = 3
X_valores3 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred3 = [regressao_polinomial(coeficientes_invertidos3, x) for x in X_valores3]

# Valores previstos da linha de regressão para N = 8
X_valores8 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred8 = [regressao_polinomial(coeficientes_invertidos8, x) for x in X_valores8]

# Plotar os dados de dispersão em vermelho e as linhas de regressão em azul, verde, preto e amarelo
plt.scatter(data[0], data[1], color='red', label='Dados de dispersão')
plt.plot(X_valores1, y_pred1, color='blue', label='Linha de Regressão (N = 1)')
plt.plot(X_valores2, y_pred2, color='green', label='Linha de Regressão (N = 2)')
plt.plot(X_valores3, y_pred3, color='black', label='Linha de Regressão (N = 3)')
plt.plot(X_valores8, y_pred8, color='yellow', label='Linha de Regressão (N = 8)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Leitura dos dados a partir do arquivo CSV
data = pd.read_csv("./data_preg.csv", header=None)

# Divisão dos dados em conjuntos de treinamento e teste
percentagem_teste = 0.10
tamanho_teste = int(percentagem_teste * len(data))
dados_teste = data.iloc[:tamanho_teste]
dados_treinamento = data.iloc[tamanho_teste:]

# Ajuste o polinômio usando numpy.polyfit para N = 1 (Regressão Linear)
grau_do_polinomio1 = 1
coeficientes_beta1 = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio1)

# Coeficientes invertidos para a regressão linear
coeficientes_invertidos1 = np.flip(coeficientes_beta1)

# Ajuste o polinômio usando numpy.polyfit para N = 2
grau_do_polinomio2 = 2
coeficientes_beta2 = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio2)

# Coeficientes invertidos para a regressão polinomial de grau 2
coeficientes_invertidos2 = np.flip(coeficientes_beta2)

# Ajuste o polinômio usando numpy.polyfit para N = 3
grau_do_polinomio3 = 3
coeficientes_beta3 = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio3)

# Coeficientes invertidos para a regressão polinomial de grau 3
coeficientes_invertidos3 = np.flip(coeficientes_beta3)

# Ajuste o polinômio usando numpy.polyfit para N = 8
grau_do_polinomio8 = 8
coeficientes_beta8 = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio8)

# Coeficientes invertidos para a regressão polinomial de grau 8
coeficientes_invertidos8 = np.flip(coeficientes_beta8)

# Crie a função de regressão polinomial
def regressao_polinomial(coeficientes, X):
    grau = len(coeficientes) - 1
    y = 0
    for i in range(grau + 1):
        y += coeficientes[i] * (X ** i)
    return y

# Valores previstos da linha de regressão para N = 1
X_valores1 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred1 = [regressao_polinomial(coeficientes_invertidos1, x) for x in X_valores1]

# Valores previstos da linha de regressão para N = 2
X_valores2 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred2 = [regressao_polinomial(coeficientes_invertidos2, x) for x in X_valores2]

# Valores previstos da linha de regressão para N = 3
X_valores3 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred3 = [regressao_polinomial(coeficientes_invertidos3, x) for x in X_valores3]

# Valores previstos da linha de regressão para N = 8
X_valores8 = np.linspace(min(data[0]), max(data[0]), 100)  # Valores de X para a linha de regressão
y_pred8 = [regressao_polinomial(coeficientes_invertidos8, x) for x in X_valores8]

# Cálculo do EQM para cada modelo nos dados de teste
# Cálculo do EQM para cada modelo nos dados de teste
eqm1_teste = np.mean((dados_teste[1] - regressao_polinomial(coeficientes_invertidos1, dados_teste[0])) ** 2)
eqm2_teste = np.mean((dados_teste[1] - regressao_polinomial(coeficientes_invertidos2, dados_teste[0])) ** 2)
eqm3_teste = np.mean((dados_teste[1] - regressao_polinomial(coeficientes_invertidos3, dados_teste[0])) ** 2)
eqm8_teste = np.mean((dados_teste[1] - regressao_polinomial(coeficientes_invertidos8, dados_teste[0])) ** 2)

print("EQM para N = 1 (Teste):", eqm1_teste)
print("EQM para N = 2 (Teste):", eqm2_teste)
print("EQM para N = 3 (Teste):", eqm3_teste)
print("EQM para N = 8 (Teste):", eqm8_teste)
# Out:
# EQM para N = 1 (Teste): 1.6067450082200563
# EQM para N = 2 (Teste): 0.4068401951628388
# EQM para N = 3 (Teste): 0.24768742822301687
# EQM para N = 8 (Teste): 23.899429974091824

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Leitura dos dados a partir do arquivo CSV
data = pd.read_csv("./data_preg.csv", header=None)

# Divisão dos dados em conjuntos de treinamento e teste
percentagem_teste = 0.10
tamanho_teste = int(percentagem_teste * len(data))
dados_teste = data.iloc[:tamanho_teste]
dados_treinamento = data.iloc[tamanho_teste:]

# Ajuste o polinômio usando numpy.polyfit para N = 8 apenas com os dados de treinamento
grau_do_polinomio8 = 8
coeficientes_beta8_treinamento = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio8)

# Coeficientes invertidos para a regressão polinomial de grau 8 com dados de treinamento
coeficientes_invertidos8_treinamento = np.flip(coeficientes_beta8_treinamento)

# Crie a função de regressão polinomial com dados de treinamento
def regressao_polinomial(coeficientes, X):
    grau = len(coeficientes) - 1
    y = 0
    for i in range(grau + 1):
        y += coeficientes[i] * (X ** i)
    return y

# Valores previstos da linha de regressão para N = 8 usando dados de treinamento
X_valores8_treinamento = np.linspace(min(dados_treinamento[0]), max(dados_treinamento[0]), 100)  # Valores de X para a linha de regressão
y_pred8_treinamento = [regressao_polinomial(coeficientes_invertidos8_treinamento, x) for x in X_valores8_treinamento]

# Plotar os dados de treinamento em vermelho e a linha de regressão em amarelo (N = 8 com dados de treinamento)
plt.scatter(dados_treinamento[0], dados_treinamento[1], color='red', label='Dados de treinamento')
plt.plot(X_valores8_treinamento, y_pred8_treinamento, color='yellow', label='Linha de Regressão (N = 8, Treinamento)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Leitura dos dados a partir do arquivo CSV
data = pd.read_csv("./data_preg.csv", header=None)

# Divisão dos dados em conjuntos de treinamento e teste
percentagem_teste = 0.10
tamanho_teste = int(percentagem_teste * len(data))
dados_teste = data.iloc[:tamanho_teste]
dados_treinamento = data.iloc[tamanho_teste:]

# Ajuste o polinômio usando numpy.polyfit para N = 1 (Regressão Linear) apenas com os dados de treinamento
grau_do_polinomio1 = 1
coeficientes_beta1_treinamento = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio1)

# Coeficientes invertidos para a regressão linear de treinamento
coeficientes_invertidos1_treinamento = np.flip(coeficientes_beta1_treinamento)

# Ajuste o polinômio usando numpy.polyfit para N = 2 apenas com os dados de treinamento
grau_do_polinomio2 = 2
coeficientes_beta2_treinamento = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio2)

# Coeficientes invertidos para a regressão polinomial de grau 2 de treinamento
coeficientes_invertidos2_treinamento = np.flip(coeficientes_beta2_treinamento)

# Ajuste o polinômio usando numpy.polyfit para N = 3 apenas com os dados de treinamento
grau_do_polinomio3 = 3
coeficientes_beta3_treinamento = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio3)

# Coeficientes invertidos para a regressão polinomial de grau 3 de treinamento
coeficientes_invertidos3_treinamento = np.flip(coeficientes_beta3_treinamento)

# Ajuste o polinômio usando numpy.polyfit para N = 8 apenas com os dados de treinamento
grau_do_polinomio8 = 8
coeficientes_beta8_treinamento = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio8)

# Coeficientes invertidos para a regressão polinomial de grau 8 de treinamento
coeficientes_invertidos8_treinamento = np.flip(coeficientes_beta8_treinamento)

# Crie a função de regressão polinomial com dados de treinamento
def regressao_polinomial(coeficientes, X):
    grau = len(coeficientes) - 1
    y = 0
    for i in range(grau + 1):
        y += coeficientes[i] * (X ** i)
    return y

# Valores previstos da linha de regressão para N = 1 usando dados de teste
y_pred1_teste = [regressao_polinomial(coeficientes_invertidos1_treinamento, x) for x in dados_teste[0]]

# Valores previstos da linha de regressão para N = 2 usando dados de teste
y_pred2_teste = [regressao_polinomial(coeficientes_invertidos2_treinamento, x) for x in dados_teste[0]]

# Valores previstos da linha de regressão para N = 3 usando dados de teste
y_pred3_teste = [regressao_polinomial(coeficientes_invertidos3_treinamento, x) for x in dados_teste[0]]

# Valores previstos da linha de regressão para N = 8 usando dados de teste
y_pred8_teste = [regressao_polinomial(coeficientes_invertidos8_treinamento, x) for x in dados_teste[0]]

# Cálculo do EQM para cada modelo nos dados de teste
eqm1_teste = np.mean((dados_teste[1] - y_pred1_teste) ** 2)
eqm2_teste = np.mean((dados_teste[1] - y_pred2_teste) ** 2)
eqm3_teste = np.mean((dados_teste[1] - y_pred3_teste) ** 2)
eqm8_teste = np.mean((dados_teste[1] - y_pred8_teste) ** 2)

print("EQM para N = 1 (Teste):", eqm1_teste)
print("EQM para N = 2 (Teste):", eqm2_teste)
print("EQM para N = 3 (Teste):", eqm3_teste)
print("EQM para N = 8 (Teste):", eqm8_teste)
# Out:
# EQM para N = 1 (Teste): 1.6067450082200563
# EQM para N = 2 (Teste): 0.4068401951628388
# EQM para N = 3 (Teste): 0.24768742822301687
# EQM para N = 8 (Teste): 23.899429974091824

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score

# Leitura dos dados a partir do arquivo CSV
data = pd.read_csv("./data_preg.csv", header=None)

# Divisão dos dados em conjuntos de treinamento e teste
percentagem_teste = 0.10
tamanho_teste = int(percentagem_teste * len(data))
dados_teste = data.iloc[:tamanho_teste]
dados_treinamento = data.iloc[tamanho_teste:]

# Ajuste o polinômio usando numpy.polyfit para N = 1 (Regressão Linear) apenas com os dados de treinamento
grau_do_polinomio1 = 1
coeficientes_beta1_treinamento = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio1)

# Coeficientes invertidos para a regressão linear de treinamento
coeficientes_invertidos1_treinamento = np.flip(coeficientes_beta1_treinamento)

# Ajuste o polinômio usando numpy.polyfit para N = 8 apenas com os dados de treinamento
grau_do_polinomio8 = 8
coeficientes_beta8_treinamento = np.polyfit(dados_treinamento[0], dados_treinamento[1], grau_do_polinomio8)

# Coeficientes invertidos para a regressão polinomial de grau 8 de treinamento
coeficientes_invertidos8_treinamento = np.flip(coeficientes_beta8_treinamento)

# Valores previstos da linha de regressão para N = 1 usando dados de treinamento
y_pred1_treinamento = [regressao_polinomial(coeficientes_invertidos1_treinamento, x) for x in dados_treinamento[0]]

# Valores previstos da linha de regressão para N = 8 usando dados de treinamento
y_pred8_treinamento = [regressao_polinomial(coeficientes_invertidos8_treinamento, x) for x in dados_treinamento[0]]

# Calcula o R-quadrado para os dados de treinamento
r_squared1_treinamento = r2_score(dados_treinamento[1], y_pred1_treinamento)
r_squared8_treinamento = r2_score(dados_treinamento[1], y_pred8_treinamento)

print("R-quadrado para N = 1 (Treinamento):", r_squared1_treinamento)
print("R-quadrado para N = 8 (Treinamento):", r_squared8_treinamento)

# Valores previstos da linha de regressão para N = 1 usando dados de teste
y_pred1_teste = [regressao_polinomial(coeficientes_invertidos1_treinamento, x) for x in dados_teste[0]]

# Valores previstos da linha de regressão para N = 8 usando dados de teste
y_pred8_teste = [regressao_polinomial(coeficientes_invertidos8_treinamento, x) for x in dados_teste[0]]

# Calcula o R-quadrado para os dados de teste
r_squared1_teste = r2_score(dados_teste[1], y_pred1_teste)
r_squared8_teste = r2_score(dados_teste[1], y_pred8_teste)

print("R-quadrado para N = 1 (Teste):", r_squared1_teste)
print("R-quadrado para N = 8 (Teste):", r_squared8_teste)
# Out:
# R-quadrado para N = 1 (Treinamento): 0.7137379053829451
# R-quadrado para N = 8 (Treinamento): 0.9040600001540002
# R-quadrado para N = 1 (Teste): -24.424581619884467
# R-quadrado para N = 8 (Teste): -377.1763782905064
